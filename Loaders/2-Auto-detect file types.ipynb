# %% [markdown]
# # pip install "unstructured[all]"

# %% [markdown]
# pip install "unstructured[pdf]"

# %%
# This uses Unstructured to figure out the file type automatically.
from langchain_community.document_loaders import DirectoryLoader, UnstructuredFileLoader
from pathlib import Path

# data_dir = r"C:\MYROOT\NOTEBOOKS\Ollama-RAG\data"                  # reliable
data_dir = Path(r"C:\MYROOT\NOTEBOOKS\Ollama-RAG\data")              # safest

loader = DirectoryLoader(
    data_dir,
    glob="**/*",
    loader_cls=UnstructuredFileLoader,
    show_progress=True,
)

docs = loader.load()
print(f"Loaded {len(docs)} documents")
# Out:
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.
#  50%|██████████████████████████████████████████                                          | 2/4 [00:27<00:30, 15.26s/it]libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.
#  75%|███████████████████████████████████████████████████████████████                     | 3/4 [00:27<00:09,  9.07s/it]
# Warning: No languages specified, defaulting to English.
# Loaded 3 documents
